# %%
# !pip install pyngrok==4.1.1
# !pip install flask_ngrok
# !pip install flask-bootstrap
# !ngrok authtoken '2UlD1Fo7cTZ7UulUtcF3tqnFwUf_39TWb9oW9LuHY6GtgEuN1'
# Out:
# ...
# Authtoken saved to configuration file: /home/mateus/.ngrok2/ngrok.yml

# %%
# flask_ngrok_example.py
import numpy as np
import random as rm
from flask import Flask
from flask_ngrok import run_with_ngrok
from flask import request
from flask import abort

import random
import time

app = Flask(__name__)
run_with_ngrok(app)  # Start ngrok when app is run

orders = 0
success = 0
successPercent = 0
errorsPercent = 0
errors = 0

@app.route("/")
def getDetails():

  global orders
  global success
  global errors
  global successPercent
  global errorsPercent
  global lastTime

  if(request.args.get('orders')):
    orders = int(request.args.get('orders'))
    success = 0
    successPercent = 0
    errorsPercent = 0
    errors = 0

    transitionName = ['success', 'error']
    transitionMatrix = [0.80,0.20]

    i = 0
    prob = 1
    while i != orders:
      change = np.random.choice(transitionName, replace=True,p=transitionMatrix)
      if change == "success":
          prob = prob * transitionMatrix[0]
          success+=1
          pass
      elif change == "error":
          prob = prob * transitionMatrix[1]
          errors+=1
      i+=1
    successPercent = success / (success+errors) * 100
    errorsPercent = errors / (success+errors) * 100
  try:
    if(orders > 30):
      # if(time.time() - lastTime < 2):
        return  '''
        <html>
            <body style= "margin: 0; padding: 0; background-color: #f5f5f5;">
              <div style="width: 70%; display: flex; margin: 0 auto; flex-direction: column; height: 100vh; align-items: center; justify-content: center;">
                <h1>Simulação RNF-02 </h1>
                <p style="text-align: center; font-size: 18 px; ">O sistema deve garantir uma precisão de 80% na categorização de ordens de compra, além de exibir a taxa de confiança da categorização efetuada (em porcentagem).</p>
                <dvi style= "width: 50%;
            display: flex;
            flex-direction: column;
            align-items: center;
            justify-content: center;
            background-color: #fff;
            padding: 16px;
            border-radius: 10px;
            box-shadow: 0px 0px 10px 0px rgba(0, 0, 0, 0.2);">
                  <h1 style="font-size: 18px;">Erro ao processar ordens de compra</h1>
                  <p style="font-size: 18px; color: red">Muitas solicitações simultâneas</p>

                  <div style="display: flex; gap: 16px; margin-top: 16px;">
                    <a href="/?orders=10"><button style="border: none;
            border-radius: 5px;
            font-size: 18px;
            background-color: #1e90ff;
            color: #fff;
            padding: 16px 32px;
            font-weight: bold;
            cursor: pointer;" value="teste">10 ordens de compra</button></a>
                    <a href="/?orders=30"><button style="border: none;
            border-radius: 5px;
            font-size: 18px;
            background-color: #1e90ff;
            color: #fff;
            padding: 16px 32px;
            font-weight: bold;
            cursor: pointer;" value="teste">30 ordens de compra</button></a>
                    <a href="/?orders=50"><button style="border: none;
            border-radius: 5px;
            font-size: 18px;
            background-color: #1e90ff;
            color: #fff;
            padding: 16px 32px;
            font-weight: bold;
            cursor: pointer;" value="teste">50 ordens de compra</button></a>
                  </div>
                </dvi>
              </div>
            </body>
          </html>
        '''
    else:
      # lastTime = time.time()
      return  '''
        <html>
            <body style= "margin: 0; padding: 0; background-color: #f5f5f5;">
              <div style="width: 70%; display: flex; margin: 0 auto; flex-direction: column; height: 100vh; align-items: center; justify-content: center;">
                <h1>Simulação RNF-02 </h1>
                <p style="text-align: center; font-size: 18 px; ">O sistema deve garantir uma precisão de 80% na categorização de ordens de compra, além de exibir a taxa de confiança da categorização efetuada (em porcentagem).</p>
                <dvi style= "width: 50%;
            display: flex;
            flex-direction: column;
            align-items: center;
            justify-content: center;
            background-color: #fff;
            padding: 16px;
            border-radius: 10px;
            box-shadow: 0px 0px 10px 0px rgba(0, 0, 0, 0.2);">
                  <p style="font-size: 18px;">Ordens de compra processadas: {orders}</p>

                  <div style="display: flex; gap: 16px;">
                    <p style="margin: 8px; text-align: center; min-width: 200px; font-size: 18px;">Categorizada corretamente</p>
                    <p style="margin: 8px; text-align: center; min-width: 200px; font-size: 18px;">Categorizada incorretamente</p>
                  </div>

                  <div style="display: flex; gap: 16px;">
                    <p style="margin: 8px; text-align: center; min-width: 200px; color: green; font-size: 18px;">{success}</p>
                    <p  style="margin: 8px; text-align: center; min-width: 200px; color: red; font-size: 18px;">{errors}</p>
                  </div>

                  <div style="display: flex; gap: 16px;">
                    <p style="margin: 8px; text-align: center; min-width: 200px; color: green; font-size: 18px;">{successPercent}%</p>
                    <p style="margin: 8px; text-align: center; min-width: 200px; color: red; font-size: 18px;">{errorsPercent}%</p>
                  </div>


                  <div style="display: flex; gap: 16px; margin-top: 16px;">
                    <a href="/?orders=10"><button style="border: none;
            border-radius: 5px;
            font-size: 18px;
            background-color: #1e90ff;
            color: #fff;
            padding: 16px 32px;
            font-weight: bold;
            cursor: pointer;" value="teste">10 ordens de compra</button></a>
                    <a href="/?orders=30"><button style="border: none;
            border-radius: 5px;
            font-size: 18px;
            background-color: #1e90ff;
            color: #fff;
            padding: 16px 32px;
            font-weight: bold;
            cursor: pointer;" value="teste">30 ordens de compra</button></a>
                    <a href="/?orders=50"><button style="border: none;
            border-radius: 5px;
            font-size: 18px;
            background-color: #1e90ff;
            color: #fff;
            padding: 16px 32px;
            font-weight: bold;
            cursor: pointer;" value="teste">50 ordens de compra</button></a>
                  </div>
                </dvi>
              </div>
            </body>
          </html>
      '''.format(orders=str(orders), success=str(success), errors=str(errors), successPercent=str(round(successPercent, 2)), errorsPercent=str(round(errorsPercent, 2)))

  except:
    return '''
      Error
    '''

if __name__ == '__main__':

  app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# /Users/marcelofeitoza/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/threading.py", line 1286, in run
#     self.function(*self.args, **self.kwargs)
# ...
